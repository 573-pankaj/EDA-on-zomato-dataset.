# %% [markdown]
# # Exploratory Data Analysis on ZOMATO Dataset

# %% [markdown]
# <img src = "ZOmato.png">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df=pd.read_csv('zomato.csv',encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %% [markdown]
# # Basic Steps for Data Analysis
# 1. Missing Values
# 2. Explore About the Numerical Variables
# 3. Explore About categorical Variables
# 4. Finding Relationship between features

# %% [markdown]
# ### Neumerical Feature

# %%
dfnew = df.select_dtypes(include=np.number)

# %%
dfnew.shape
# Out:
# (9551, 8)

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Country Code          9551 non-null   int64
#  2   Longitude             9551 non-null   float64
#  3   Latitude              9551 non-null   float64
#  4   Average Cost for two  9551 non-null   int64
#  5   Price range           9551 non-null   int64
#  6   Aggregate rating      9551 non-null   float64
#  7   Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5)
# memory usage: 597.1 KB

# %%
# trying to find out relationship, if any !!!!
sns.lineplot(x = 'Price range', y = 'Aggregate rating', data = df)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Aggregate rating'>

# %%
df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
df['Rating color'].value_counts()
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %%
sns.lineplot(y = 'Price range', x = 'Rating color'  ,data = df)
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='Price range'>

# %%
sns.kdeplot(dfnew['Price range'], shade=True, cbar = True, bw = 1, cut = 0)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Density'>

# %%
sns.pairplot(dfnew)

# %%
dfnew.head()
# Out:
#    Restaurant ID  Country Code   Longitude   Latitude  Average Cost for two  \
# 0        6317637           162  121.027535  14.565443                  1100
# 1        6304287           162  121.014101  14.553708                  1200
# 2        6300002           162  121.056831  14.581404                  4000
# 3        6318506           162  121.056475  14.585318                  1500
# 4        6314302           162  121.057508  14.584450                  1500
#
#    Price range  Aggregate rating  Votes
# 0            3               4.8    314
# 1            3               4.5    591
# 2            4               4.4    270
# 3            4               4.9    365
# 4            4               4.8    229

# %% [markdown]
# #### Categorical Feature

# %%
dfcat = df.select_dtypes(exclude=np.number)

# %%
dfcat.shape
# Out:
# (9551, 13)

# %%
dfcat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9551 non-null   object
#  1   City                  9551 non-null   object
#  2   Address               9551 non-null   object
#  3   Locality              9551 non-null   object
#  4   Locality Verbose      9551 non-null   object
#  5   Cuisines              9542 non-null   object
#  6   Currency              9551 non-null   object
#  7   Has Table booking     9551 non-null   object
#  8   Has Online delivery   9551 non-null   object
#  9   Is delivering now     9551 non-null   object
#  10  Switch to order menu  9551 non-null   object
#  11  Rating color          9551 non-null   object
#  12  Rating text           9551 non-null   object
# dtypes: object(13)
# memory usage: 970.1+ KB

# %%
dfcat.head()
# Out:
#           Restaurant Name              City  \
# 0        Le Petit Souffle       Makati City
# 1        Izakaya Kikufuji       Makati City
# 2  Heat - Edsa Shangri-La  Mandaluyong City
# 3                    Ooma  Mandaluyong City
# 4             Sambo Kojin  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose  \
# ...

# %%
sns.catplot(x = 'Rating color' , y = 'Price range', kind = 'box', data = df)

# %%
df['Has Online delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
sns.catplot(x = 'Has Online delivery' , y = 'Price range', kind = 'box', data = df)

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %% [markdown]
# #### Extract the feature which some values are missing

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ##### observasion :
#     the column "Cuisines" has 9 missing value

# %%
sns.heatmap(df.isnull(), yticklabels=False,cmap='viridis')   # cmap='viridis', "tab20"  cbar=False, yticklabels=False,  cmap ='viridis'
# Out:
# <AxesSubplot:>

# %%
df_country=pd.read_excel('Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_country.shape
# Out:
# (15, 2)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# ###### 'Country Code' is present in both the data table

# %% [markdown]
# ##### Merging two data frame

# %%
final_df=pd.merge(df,df_country,on='Country Code', how='left')

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
##To check Data Types
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
country_value_count = final_df.Country.value_counts()

# %%
country_value_count
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
sns.countplot(x='Country',data=final_df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %% [markdown]
# ###### Observation:
#     ZOMATO has maximum markate on india

# %%
country_names = final_df.Country.value_counts().index

# %%
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
country_val=final_df.Country.value_counts().values

# %%
country_val
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %% [markdown]
# ### Pie Chart- Top 3 countries that uses zomato

# %%
colors = sns.color_palette('bright')[0:5] # 
explode = [0.4,0.03,0.02]
plt.rcParams['figure.figsize'] = (13, 9)
plt.pie(country_val[:3],labels=country_names[:3], colors = colors, explode = explode, autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1bec04a0b20>,
# ...
#  [Text(-1.4767830955843777, 0.2628910203795917, 'India'),
#   Text(1.1066621262703111, -0.22847086965053934, 'United States'),
#   Text(1.1195789974801635, -0.03070616226935929, 'United Kingdom')],
#  [Text(-0.9845220637229184, 0.17526068025306113, '94.39%'),
#   Text(0.6169886190710584, -0.12737756449543342, '4.73%'),
#   Text(0.6197669450336619, -0.01699805411339532, '0.87%')])

# %% [markdown]
# ###### Observation:
#       Zomatos maximum profits and transaction are from India
#       After that USA and then United Kingdoms

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df['Rating text'].shape
# Out:
# (9551,)

# %%
final_df['Rating text'].value_counts()
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %%
total  = 3737 + 2148 + 2100 + 1079 + 301 + 186

# %%
avg_per = (3737/total)*100
avg_per
# Out:
# 39.12679300596796

# %%
NOT_Rated_per = (2148/total)*100
NOT_Rated_per
# Out:
# 22.489791644853945

# %%
Good_per = (2100/total)*100
Good_per
# Out:
# 21.987226468432624

# %%
Very_Good_per = ( 1079/total)*100
Very_Good_per
# Out:
# 11.297246361637525

# %%
Excellent_per = ( 301/total)*100   
Excellent_per
# Out:
# 3.151502460475343

# %%
Poor_per = (186/total)*100   
Poor_per
# Out:
# 1.947440058632604

# %%
sns.countplot(x='Rating text',data=final_df,palette=['blue','red','orange','yellow','green','green']) #palette=['blue','red','orange','yellow','green','green']
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='count'>

# %%
final_df['Rating color'].value_counts()
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %%
## Count plot
sns.countplot(x="Rating color",data=final_df)
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
final_df['Aggregate rating'].value_counts()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
sns.countplot(x='Aggregate rating',data=final_df)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='count'>

# %%
ratings=final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ## Observation
#     1. When Rating is between 4.5 to 4.9 --->  Excellent
#     2. When Rating are between 4.0 to 3.4 ---> very good
#     3. when Rating is between 3.5 to 3.9 ----> good
#     4. when Rating is between 3.0 to 3.4 ----> average
#     5. when Rating is between 2.5 to 2.9 ----> average
#     6. when Rating is between 2.0 to 2.4 ----> Poor

# %%
ratings.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
ratings.tail()
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 28               4.5   Dark Green   Excellent            95
# 29               4.6   Dark Green   Excellent            78
# 30               4.7   Dark Green   Excellent            42
# 31               4.8   Dark Green   Excellent            25
# 32               4.9   Dark Green   Excellent            61

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12, 6)
sns.barplot(x="Aggregate rating",y="Rating Count",data=ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# ###### Observation :
#     1. we can see there are more number are people who does not give any ratings
#     2. we can see very high ratings are also low
#     3. mostly people give ratins between 2.8 to 4.1

# %%
sns.barplot(x="Aggregate rating",y="Rating Count",hue='Rating color',data=ratings,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# Observation:
# 1. Not Rated count is very high
# 2. Maximum number of rating are between 2.5 to 4.2

# %%
## Count plot
sns.countplot(x="Rating color",data=ratings,palette=['blue','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ### Find out the countries name that has given 0 rating

# %%
final_df[final_df['Rating color']=='White'].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
final_df['Rating color'].value_counts()
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %%
Observation :

# %%
Rating_Zero_percentage  = (2139/8652)*100
Rating_Zero_percentage
# Out:
# 24.72260748959778

# %%
final_df.groupby(['Aggregate rating','Country']).size().reset_index().head(10)
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3
# 4               1.8           India     1
# 5               1.9           India     2
# 6               2.0           India     7
# 7               2.1           India    15
# 8               2.2           India    26
# 9               2.2   United States     1

# %% [markdown]
# ###### Observations :
#       Maximum number of 0 ratings are from Indian customers

# %% [markdown]
# #### Find out which currency is used by which country?

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df[['Country','Currency']].groupby(['Country','Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %% [markdown]
# ## Which Countries do have online deliveries option

# %%
final_df[final_df['Has Online delivery'] == "Yes"].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %% [markdown]
# ###### Observation :
#     India and UAE has online delivery options

# %%
final_df[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %% [markdown]
# ###### Observations:
#        1. ONLY Online Deliveries are available in India and UAE

# %% [markdown]
# ## Ceck for top 5 cities which utilizes zomzto services maximum

# %%
final_df.City.value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
final_df.City.value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad',
#        'Bhubaneshwar', 'Amritsar', 'Ahmedabad', 'Lucknow', 'Guwahati',
#        ...
#        'Ojo Caliente', 'Montville', 'Monroe', 'Miller', 'Middleton Beach',
#        'Panchkula', 'Mc Millan', 'Mayfield', 'Macedon', 'Vineland Station'],
#       dtype='object', length=141)

# %%
city_values=final_df.City.value_counts().values
city_labels=final_df.City.value_counts().index

# %%
plt.rcParams['figure.figsize'] = (13, 9)
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1bec677cd90>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %% [markdown]
# # TOP 10 city which uses ZOMATO has maximum customers

# %%
plt.bar(city_labels[:10],city_values[:10],color='green')
plt.xticks(city_labels[:10], color='green', rotation=45, fontweight='bold', fontsize='17', horizontalalignment='right')
plt.show()

# %% [markdown]
# ### These are the TOP 5 cities where maximum profit accuired by ZOMATO

# %%
plt.bar(city_labels[:5],city_values[:5],color='magenta')
plt.xticks(city_labels[:5], color='green', rotation=45, fontweight='bold', fontsize='17', horizontalalignment='right')
plt.show()

# %% [markdown]
# # Find the top 10 cuisines

# %%
final_df['Cuisines'].value_counts()
# Out:
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
final_df.Cuisines.value_counts().index
# Out:
# Index(['North Indian', 'North Indian, Chinese', 'Chinese', 'Fast Food',
#        'North Indian, Mughlai', 'Cafe', 'Bakery',
#        'North Indian, Mughlai, Chinese', 'Bakery, Desserts', 'Street Food',
#        ...
#        'Cafe, Pizza, Burger',
#        'Healthy Food, Continental, Juices, Beverages, Italian, Salad, Lebanese',
#        'Goan, American, Portuguese', 'South Indian, Desserts, Beverages',
#        'Healthy Food, North Indian, Italian, Salad', 'Bengali, Fast Food',
#        'North Indian, Rajasthani, Asian',
#        'Chinese, Thai, Malaysian, Indonesian',
#        'Bakery, Desserts, North Indian, Bengali, South Indian',
#        'Italian, World Cuisine'],
#       dtype='object', length=1825)

# %%
Cusines_values=final_df.Cuisines.value_counts().values
cusines_labels=final_df.Cuisines.value_counts().index

# %%
cusines_labels[:10]
# Out:
# Index(['North Indian', 'North Indian, Chinese', 'Chinese', 'Fast Food',
#        'North Indian, Mughlai', 'Cafe', 'Bakery',
#        'North Indian, Mughlai, Chinese', 'Bakery, Desserts', 'Street Food'],
#       dtype='object')

# %%
plt.bar(cusines_labels[:10],Cusines_values[:10],color='green')
plt.xticks( cusines_labels[:10], color='black', rotation=45, fontweight='bold', fontsize='17', horizontalalignment='right')
plt.show()

# %% [markdown]
# ###### observation :
#     This are the top rated Cusines of ZOMATO, and these are the mostl profitable Cusines

# %%
len(Cusines_values)
# Out:
# 1825

# %%
len(cusines_labels)
# Out:
# 1825

# %%
plt.bar(cusines_labels[1815:],Cusines_values[1815:],color='red')
plt.xticks( cusines_labels[1815:], color='black', rotation=45, fontweight='bold', fontsize='17', horizontalalignment='right')
plt.show()

# %% [markdown]
# ###### observation :
#     These are the super Low rated Cusines of ZOMATO, and here we can think of better business plan .

# %% [markdown]
# ##### CONCLUSION :
#     1. 'New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad' this are the top profitable cyties.
#     so I would like to make a strategy on the cyties like 'Panchkula', 'Mc Millan', 'Mayfield', 'Macedon', 'Vineland Station'
#     which has very low contribution in terms of profit, Why so, We have to study about that
#     2. We can see that Zomato has maximum profit  from Inida followed by United States
#     United Kingdom .
#     3. Based on this dataset we can noticed that after having service from ZOMATO
#         1) 39.12 % customers give Agerage as a rating
#         2) 22.48 % customers does not give any rating
#         3) 21.29 % customers gives Good as a rating
#         4) Only 3.15 % customers gives Excellent as a rating
#         5) 1.94 % customers gives poor as a rating
#     work need to be done to have more profit that is we have to focuse on the 22.48% customers why they did not give any
#     ratings and those customers who gives very low ratings .

# %% [markdown]
# <img src="THEND.jfif">

# %% [markdown]
# ###### By PANKAJ KUMAR BARMAN
#          Msc CSMI , 1st year student at RAMAKRISHNA MISSION VIDYAMANDIRA, Belur Math
